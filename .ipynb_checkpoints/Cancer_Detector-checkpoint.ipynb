# %% [markdown]
# # Skin Cancer Detector with HAM10000

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import tensorflow as tf
from sklearn import preprocessing

# %% [markdown]
# ### LOAD DATA
# The dataset contains 10015 images divided in two parts. The 'HAM10000_metadata.csv' contains the ground truth of the dataset. Here we can use this file to retrieve the images from the relative folders and also analyse what the images are.

# %%
path = '.'
file_name = os.path.join(path, 'HAM10000_metadata.csv')
df = pd.read_csv(file_name, na_values=['NA','?'])
disease_types = pd.unique(df['dx'])
print(disease_types)
# Out:
# ['bkl' 'nv' 'df' 'mel' 'vasc' 'bcc' 'akiec']

# %% [markdown]
# As you can see from the last print, there are 7 types of images classified in the dataset. Let's create a dictionary to better represent those diseases and then replace those with the full name of the skin patology.

# %%
images_type = {'bkl': 'Benign Keratosis', 'nv': 'Melanocytic Nevi',
                      'df': 'Dermatofibroma', 'mel': 'Melanoma',
                      'vasc': 'Vascular Lesions', 'bcc': 'Basal Cell Carcinoma',
                      'akiec': "Bowen's disease"}
images_type
df.replace(images_type.keys(), images_type.values(), inplace=True)
df[:5]
# Out:
#      lesion_id      image_id                dx dx_type   age   sex  \
# 0  HAM_0000118  ISIC_0027419  Benign Keratosis   histo  80.0  male
# 1  HAM_0000118  ISIC_0025030  Benign Keratosis   histo  80.0  male
# 2  HAM_0002730  ISIC_0026769  Benign Keratosis   histo  80.0  male
# 3  HAM_0002730  ISIC_0025661  Benign Keratosis   histo  80.0  male
# 4  HAM_0001466  ISIC_0031633  Benign Keratosis   histo  75.0  male
#
#   localization
# 0        scalp
# 1        scalp
# 2        scalp
# 3        scalp
# 4          ear

# %%
# We can observe also that the ages range, varies between 0 and 80.
# This information will be useful in the final analysis 
# because we could tell wheter if the age is an increasing 
# factor of skin cancer or not.
age_range = pd.unique(df['age'])
age_range
# Out:
# array([80., 75., 60., 70., 55., 85., 65., 40., 50., 45., 35.,  0., 30.,
#        nan,  5., 25., 20., 10., 15.])

# %%
# It is also possible to locate where different tumors where found in the 
# patients
cancers_location = pd.unique(df['localization'])
cancers_location
# Out:
# array(['scalp', 'ear', 'face', 'back', 'trunk', 'chest',
#        'upper extremity', 'abdomen', 'unknown', 'lower extremity',
#        'genital', 'neck', 'hand', 'foot', 'acral'], dtype=object)

# %% [markdown]
# The dataset has been developed during the last 20 years and most of the images have been classified manually using a process that in medicine is called 'Histopathology' (histo) which entails to microscopically analyse a small portion of the skin tissue and then classifying it accordigly. There are also images which has been classified by the use of a tool called Cofocal Microscopy (cofocal) which allowed medicians to correctly identify where there's a disease and where it's not. Finally the data contains also a series of images that have not been classified rigorously, denoted by 'follow_up' (data that needs follow-up examination) and 'consensus' data that has been classified by the consensus of a medician. Since these last three categories do not represent a rigorous result, we decided to exclude them from the scope of the analysis.

# %%
classification_type = pd.unique(df['dx_type'])
print(classification_type)
# Drop the rows that have the 'consensus' or 'follow_up' value in the column 'dx_type'
indexes_consensus = df[df['dx_type'] == 'consensus'].index
indexes_follow_up = df[df['dx_type'] == 'follow_up'].index
df.drop(indexes_consensus, inplace=True)
df.drop(indexes_follow_up, inplace=True)
classification_type = pd.unique(df['dx_type'])
classification_type
# Out:
# ['histo' 'consensus' 'confocal' 'follow_up']
# array(['histo', 'confocal'], dtype=object)

# %% [markdown]
# After having deleted the pieces of data that are not relevant for the analysis, we now check if there are any missing values.

# %%
df.isnull().any()
# Out:
# lesion_id       False
# image_id        False
# dx              False
# dx_type         False
# age              True
# sex             False
# localization    False
# dtype: bool

# %% [markdown]
# From the analysis, it appears that the column of the 'age' has some missing values. To solve this problem we decided to fill those missing values with the median value.

# %%
median = df['age'].median()
df['age'] = df['age'].fillna(median)
df.isnull().any()
# Out:
# lesion_id       False
# image_id        False
# dx              False
# dx_type         False
# age             False
# sex             False
# localization    False
# dtype: bool

# %% [markdown]
# In order to build a system capable to be trained and to give us results, it is crucial to encode the different types of skin cancer into  labels, to classify them. This is achieved using sklearn by the following code.

# %%
encoder = preprocessing.LabelEncoder()
labels = encoder.fit_transform(df['dx'])
df['target'] = labels
df[:10]
# Out:
#      lesion_id      image_id                dx dx_type   age     sex  \
# 0  HAM_0000118  ISIC_0027419  Benign Keratosis   histo  80.0    male
# 1  HAM_0000118  ISIC_0025030  Benign Keratosis   histo  80.0    male
# 2  HAM_0002730  ISIC_0026769  Benign Keratosis   histo  80.0    male
# 3  HAM_0002730  ISIC_0025661  Benign Keratosis   histo  80.0    male
# 4  HAM_0001466  ISIC_0031633  Benign Keratosis   histo  75.0    male
# 5  HAM_0001466  ISIC_0027850  Benign Keratosis   histo  75.0    male
# 6  HAM_0002761  ISIC_0029176  Benign Keratosis   histo  60.0    male
# 7  HAM_0002761  ISIC_0029068  Benign Keratosis   histo  60.0    male
# 8  HAM_0005132  ISIC_0025837  Benign Keratosis   histo  70.0  female
# 9  HAM_0005132  ISIC_0025209  Benign Keratosis   histo  70.0  female
#
#   localization  target
# 0        scalp       1
# 1        scalp       1
# 2        scalp       1
# 3        scalp       1
# 4          ear       1
# 5          ear       1
# 6         face       1
# 7         face       1
# 8         back       1
# 9         back       1

# %% [markdown]
# Now we would like to count the numbers of skin cancers according to each category to see if the dataset is well balanced or not.

# %% [markdown]
# Now we are going to load the images and adapt them to the best of our possibilities with respect to the size. The images in the dataset comes with two directories, part-1 and part-2. We are going to retrieve those images in two different variables and then unify in one big piece of data.

# %%
for row in df.values:
    print(row)
# Out:
# ['HAM_0000118' 'ISIC_0027419' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0000118' 'ISIC_0025030' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0002730' 'ISIC_0026769' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0002730' 'ISIC_0025661' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0001466' 'ISIC_0031633' 'Benign Keratosis' 'histo' 75.0 'male' 'ear'
#  1]
# ['HAM_0001466' 'ISIC_0027850' 'Benign Keratosis' 'histo' 75.0 'male' 'ear'
#  1]
# ['HAM_0002761' 'ISIC_0029176' 'Benign Keratosis' 'histo' 60.0 'male'
#  'face' 1]
# ['HAM_0002761' 'ISIC_0029068' 'Benign Keratosis' 'histo' 60.0 'male'
#  'face' 1]
# ['HAM_0005132' 'ISIC_0025837' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0005132' 'ISIC_0025209' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0001396' 'ISIC_0025276' 'Benign Keratosis' 'histo' 55.0 'female'
#  'trunk' 1]
# ['HAM_0004234' 'ISIC_0029396' 'Benign Keratosis' 'histo' 85.0 'female'
#  'chest' 1]
# ['HAM_0004234' 'ISIC_0025984' 'Benign Keratosis' 'histo' 85.0 'female'
#  'chest' 1]
# ['HAM_0001949' 'ISIC_0025767' 'Benign Keratosis' 'histo' 70.0 'male'
#  'trunk' 1]
# ['HAM_0001949' 'ISIC_0032417' 'Benign Keratosis' 'histo' 70.0 'male'
#  'trunk' 1]
# ['HAM_0007207' 'ISIC_0031326' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0001601' 'ISIC_0025915' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0001601' 'ISIC_0031029' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0007571' 'ISIC_0029836' 'Benign Keratosis' 'histo' 70.0 'male'
#  'chest' 1]
# ['HAM_0007571' 'ISIC_0032129' 'Benign Keratosis' 'histo' 70.0 'male'
#  'chest' 1]
# ['HAM_0006071' 'ISIC_0032343' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0003301' 'ISIC_0025033' 'Benign Keratosis' 'histo' 60.0 'male'
#  'back' 1]
# ['HAM_0003301' 'ISIC_0027310' 'Benign Keratosis' 'histo' 60.0 'male'
#  'back' 1]
# ['HAM_0004884' 'ISIC_0032128' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0004884' 'ISIC_0025937' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0002521' 'ISIC_0027828' 'Benign Keratosis' 'histo' 40.0 'male'
#  'upper extremity' 1]
# ['HAM_0002521' 'ISIC_0029291' 'Benign Keratosis' 'histo' 40.0 'male'
#  'upper extremity' 1]
# ['HAM_0006574' 'ISIC_0030698' 'Benign Keratosis' 'histo' 40.0 'male'
#  'back' 1]
# ['HAM_0006574' 'ISIC_0025567' 'Benign Keratosis' 'histo' 40.0 'male'
#  'back' 1]
# ['HAM_0001480' 'ISIC_0031753' 'Benign Keratosis' 'histo' 70.0 'male'
#  'abdomen' 1]
# ['HAM_0001480' 'ISIC_0026835' 'Benign Keratosis' 'histo' 70.0 'male'
#  'abdomen' 1]
# ['HAM_0005772' 'ISIC_0031159' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0005772' 'ISIC_0031017' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0005612' 'ISIC_0024981' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0005388' 'ISIC_0027815' 'Benign Keratosis' 'histo' 80.0 'male'
#  'chest' 1]
# ['HAM_0000351' 'ISIC_0024324' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0000351' 'ISIC_0029559' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0003847' 'ISIC_0030661' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0003847' 'ISIC_0027053' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0003847' 'ISIC_0028560' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0003847' 'ISIC_0031650' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0000164' 'ISIC_0029161' 'Benign Keratosis' 'histo' 60.0 'male'
#  'chest' 1]
# ['HAM_0000164' 'ISIC_0026273' 'Benign Keratosis' 'histo' 60.0 'male'
#  'chest' 1]
# ['HAM_0007409' 'ISIC_0025076' 'Benign Keratosis' 'histo' 50.0 'male'
#  'upper extremity' 1]
# ['HAM_0007409' 'ISIC_0029687' 'Benign Keratosis' 'histo' 50.0 'male'
#  'upper extremity' 1]
# ['HAM_0007409' 'ISIC_0025642' 'Benign Keratosis' 'histo' 50.0 'male'
#  'upper extremity' 1]
# ['HAM_0002299' 'ISIC_0025819' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0002299' 'ISIC_0032013' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0007010' 'ISIC_0031691' 'Benign Keratosis' 'histo' 40.0 'male'
#  'trunk' 1]
# ['HAM_0007010' 'ISIC_0025419' 'Benign Keratosis' 'histo' 40.0 'male'
#  'trunk' 1]
# ['HAM_0003670' 'ISIC_0030105' 'Benign Keratosis' 'histo' 80.0 'female'
#  'unknown' 1]
# ['HAM_0007125' 'ISIC_0025016' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0007125' 'ISIC_0029147' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0001221' 'ISIC_0029301' 'Benign Keratosis' 'histo' 45.0 'male'
#  'upper extremity' 1]
# ['HAM_0001221' 'ISIC_0026637' 'Benign Keratosis' 'histo' 45.0 'male'
#  'upper extremity' 1]
# ['HAM_0001983' 'ISIC_0030377' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0003569' 'ISIC_0027960' 'Benign Keratosis' 'histo' 75.0 'male'
#  'unknown' 1]
# ['HAM_0003569' 'ISIC_0026955' 'Benign Keratosis' 'histo' 75.0 'male'
#  'unknown' 1]
# ['HAM_0000700' 'ISIC_0028052' 'Benign Keratosis' 'histo' 60.0 'male'
#  'face' 1]
# ['HAM_0000728' 'ISIC_0025286' 'Benign Keratosis' 'histo' 50.0 'male'
#  'lower extremity' 1]
# ['HAM_0003021' 'ISIC_0031468' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0003021' 'ISIC_0030926' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0000959' 'ISIC_0029288' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0000959' 'ISIC_0031008' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0004569' 'ISIC_0031495' 'Benign Keratosis' 'histo' 40.0 'male'
#  'upper extremity' 1]
# ['HAM_0004569' 'ISIC_0026104' 'Benign Keratosis' 'histo' 40.0 'male'
#  'upper extremity' 1]
# ['HAM_0004641' 'ISIC_0025099' 'Benign Keratosis' 'histo' 60.0 'male'
#  'abdomen' 1]
# ['HAM_0004641' 'ISIC_0031485' 'Benign Keratosis' 'histo' 60.0 'male'
#  'abdomen' 1]
# ['HAM_0005801' 'ISIC_0029413' 'Benign Keratosis' 'histo' 70.0 'female'
#  'abdomen' 1]
# ['HAM_0005801' 'ISIC_0029576' 'Benign Keratosis' 'histo' 70.0 'female'
#  'abdomen' 1]
# ['HAM_0004341' 'ISIC_0031967' 'Benign Keratosis' 'histo' 70.0 'female'
#  'scalp' 1]
# ['HAM_0004341' 'ISIC_0031584' 'Benign Keratosis' 'histo' 70.0 'female'
#  'scalp' 1]
# ['HAM_0000907' 'ISIC_0025140' 'Benign Keratosis' 'histo' 75.0 'male' 'ear'
#  1]
# ['HAM_0000907' 'ISIC_0025554' 'Benign Keratosis' 'histo' 75.0 'male' 'ear'
#  1]
# ['HAM_0001469' 'ISIC_0029289' 'Benign Keratosis' 'histo' 60.0 'female'
#  'trunk' 1]
# ['HAM_0001469' 'ISIC_0029912' 'Benign Keratosis' 'histo' 60.0 'female'
#  'trunk' 1]
# ['HAM_0001728' 'ISIC_0033539' 'Benign Keratosis' 'histo' 60.0 'male'
#  'back' 1]
# ['HAM_0003021' 'ISIC_0032283' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0003021' 'ISIC_0030005' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0000959' 'ISIC_0030189' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0000959' 'ISIC_0026532' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0001773' 'ISIC_0024832' 'Benign Keratosis' 'histo' 40.0 'female'
#  'face' 1]
# ['HAM_0001773' 'ISIC_0026958' 'Benign Keratosis' 'histo' 40.0 'female'
#  'face' 1]
# ['HAM_0002127' 'ISIC_0030768' 'Benign Keratosis' 'histo' 40.0 'male'
#  'face' 1]
# ['HAM_0002127' 'ISIC_0029837' 'Benign Keratosis' 'histo' 40.0 'male'
#  'face' 1]
# ['HAM_0002092' 'ISIC_0031624' 'Benign Keratosis' 'histo' 35.0 'female'
#  'lower extremity' 1]
# ['HAM_0002092' 'ISIC_0025510' 'Benign Keratosis' 'histo' 35.0 'female'
#  'lower extremity' 1]
# ['HAM_0005075' 'ISIC_0030607' 'Benign Keratosis' 'histo' 80.0 'male'
#  'upper extremity' 1]
# ['HAM_0005075' 'ISIC_0029060' 'Benign Keratosis' 'histo' 80.0 'male'
#  'upper extremity' 1]
# ['HAM_0002921' 'ISIC_0029308' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0003410' 'ISIC_0024635' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0003410' 'ISIC_0029425' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0004852' 'ISIC_0028774' 'Benign Keratosis' 'histo' 65.0 'male'
#  'face' 1]
# ['HAM_0004852' 'ISIC_0030565' 'Benign Keratosis' 'histo' 65.0 'male'
#  'face' 1]
# ['HAM_0000746' 'ISIC_0027023' 'Benign Keratosis' 'histo' 60.0 'male'
#  'face' 1]
# ['HAM_0001473' 'ISIC_0029022' 'Benign Keratosis' 'histo' 70.0 'male'
#  'face' 1]
# ['HAM_0003007' 'ISIC_0025388' 'Benign Keratosis' 'histo' 40.0 'female'
#  'abdomen' 1]
# ['HAM_0003007' 'ISIC_0028080' 'Benign Keratosis' 'histo' 40.0 'female'
#  'abdomen' 1]
# ['HAM_0002957' 'ISIC_0026153' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0002957' 'ISIC_0025876' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0002985' 'ISIC_0025063' 'Benign Keratosis' 'histo' 85.0 'male'
#  'face' 1]
# ['HAM_0003326' 'ISIC_0032463' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0003326' 'ISIC_0025548' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0001853' 'ISIC_0032306' 'Benign Keratosis' 'histo' 55.0 'male'
#  'face' 1]
# ['HAM_0006558' 'ISIC_0032304' 'Benign Keratosis' 'histo' 65.0 'female'
#  'genital' 1]
# ['HAM_0006558' 'ISIC_0031639' 'Benign Keratosis' 'histo' 65.0 'female'
#  'genital' 1]
# ['HAM_0001665' 'ISIC_0027957' 'Benign Keratosis' 'histo' 50.0 'male'
#  'lower extremity' 1]
# ['HAM_0001665' 'ISIC_0031212' 'Benign Keratosis' 'histo' 50.0 'male'
#  'lower extremity' 1]
# ['HAM_0001417' 'ISIC_0032382' 'Benign Keratosis' 'histo' 55.0 'male'
#  'face' 1]
# ['HAM_0001417' 'ISIC_0027533' 'Benign Keratosis' 'histo' 55.0 'male'
#  'face' 1]
# ['HAM_0000114' 'ISIC_0029674' 'Benign Keratosis' 'histo' 65.0 'male'
#  'face' 1]
# ['HAM_0000114' 'ISIC_0028607' 'Benign Keratosis' 'histo' 65.0 'male'
#  'face' 1]
# ['HAM_0003458' 'ISIC_0024623' 'Benign Keratosis' 'histo' 85.0 'female'
#  'chest' 1]
# ['HAM_0003458' 'ISIC_0029613' 'Benign Keratosis' 'histo' 85.0 'female'
#  'chest' 1]
# ['HAM_0004673' 'ISIC_0029418' 'Benign Keratosis' 'histo' 50.0 'male'
#  'back' 1]
# ['HAM_0004673' 'ISIC_0027455' 'Benign Keratosis' 'histo' 50.0 'male'
#  'back' 1]
# ['HAM_0007179' 'ISIC_0025906' 'Benign Keratosis' 'histo' 0.0 'female'
#  'back' 1]
# ['HAM_0007179' 'ISIC_0027151' 'Benign Keratosis' 'histo' 0.0 'female'
#  'back' 1]
# ['HAM_0005077' 'ISIC_0028646' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0000566' 'ISIC_0026794' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0000344' 'ISIC_0034318' 'Benign Keratosis' 'histo' 55.0 'male'
#  'trunk' 1]
# ['HAM_0000344' 'ISIC_0032972' 'Benign Keratosis' 'histo' 55.0 'male'
#  'trunk' 1]
# ['HAM_0004332' 'ISIC_0032534' 'Benign Keratosis' 'histo' 55.0 'male'
#  'trunk' 1]
# ['HAM_0004332' 'ISIC_0033785' 'Benign Keratosis' 'histo' 55.0 'male'
#  'trunk' 1]
# ['HAM_0004332' 'ISIC_0033184' 'Benign Keratosis' 'histo' 55.0 'male'
#  'trunk' 1]
# ['HAM_0003321' 'ISIC_0032929' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0003321' 'ISIC_0032963' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0006085' 'ISIC_0032949' 'Benign Keratosis' 'histo' 85.0 'female'
#  'face' 1]
# ['HAM_0006085' 'ISIC_0033322' 'Benign Keratosis' 'histo' 85.0 'female'
#  'face' 1]
# ['HAM_0006085' 'ISIC_0033127' 'Benign Keratosis' 'histo' 85.0 'female'
#  'face' 1]
# ['HAM_0002040' 'ISIC_0033041' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0002040' 'ISIC_0033900' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0002040' 'ISIC_0033361' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0005299' 'ISIC_0032732' 'Benign Keratosis' 'histo' 55.0 'female'
#  'lower extremity' 1]
# ['HAM_0005299' 'ISIC_0032778' 'Benign Keratosis' 'histo' 55.0 'female'
#  'lower extremity' 1]
# ['HAM_0005299' 'ISIC_0033466' 'Benign Keratosis' 'histo' 55.0 'female'
#  'lower extremity' 1]
# ['HAM_0004075' 'ISIC_0030276' 'Benign Keratosis' 'histo' 60.0 'male'
#  'face' 1]
# ['HAM_0000112' 'ISIC_0033583' 'Benign Keratosis' 'histo' 55.0 'female'
#  'face' 1]
# ['HAM_0000112' 'ISIC_0033465' 'Benign Keratosis' 'histo' 55.0 'female'
#  'face' 1]
# ['HAM_0002774' 'ISIC_0029683' 'Benign Keratosis' 'histo' 65.0 'male'
#  'unknown' 1]
# ['HAM_0006663' 'ISIC_0033482' 'Benign Keratosis' 'histo' 85.0 'female'
#  'lower extremity' 1]
# ['HAM_0006663' 'ISIC_0033201' 'Benign Keratosis' 'histo' 85.0 'female'
#  'lower extremity' 1]
# ['HAM_0003001' 'ISIC_0032514' 'Benign Keratosis' 'histo' 75.0 'male'
#  'face' 1]
# ['HAM_0006654' 'ISIC_0033691' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0006654' 'ISIC_0033910' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0006654' 'ISIC_0032556' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0003743' 'ISIC_0033646' 'Benign Keratosis' 'histo' 50.0 'male'
#  'upper extremity' 1]
# ['HAM_0003743' 'ISIC_0033592' 'Benign Keratosis' 'histo' 50.0 'male'
#  'upper extremity' 1]
# ['HAM_0003743' 'ISIC_0033899' 'Benign Keratosis' 'histo' 50.0 'male'
#  'upper extremity' 1]
# ['HAM_0007101' 'ISIC_0032842' 'Benign Keratosis' 'histo' 60.0 'male'
#  'lower extremity' 1]
# ['HAM_0007101' 'ISIC_0032618' 'Benign Keratosis' 'histo' 60.0 'male'
#  'lower extremity' 1]
# ['HAM_0007101' 'ISIC_0032513' 'Benign Keratosis' 'histo' 60.0 'male'
#  'lower extremity' 1]
# ['HAM_0006938' 'ISIC_0033716' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0006938' 'ISIC_0034011' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0006938' 'ISIC_0033613' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0003770' 'ISIC_0032877' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0003770' 'ISIC_0034175' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0003770' 'ISIC_0033523' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0003768' 'ISIC_0029929' 'Benign Keratosis' 'histo' 80.0 'male'
#  'upper extremity' 1]
# ['HAM_0000779' 'ISIC_0032978' 'Benign Keratosis' 'histo' 70.0 'male'
#  'chest' 1]
# ['HAM_0005386' 'ISIC_0033973' 'Benign Keratosis' 'histo' 45.0 'male'
#  'back' 1]
# ['HAM_0005386' 'ISIC_0033761' 'Benign Keratosis' 'histo' 45.0 'male'
#  'back' 1]
# ['HAM_0005386' 'ISIC_0033505' 'Benign Keratosis' 'histo' 45.0 'male'
#  'back' 1]
# ['HAM_0001385' 'ISIC_0033280' 'Benign Keratosis' 'histo' 50.0 'female'
#  'neck' 1]
# ['HAM_0001385' 'ISIC_0033212' 'Benign Keratosis' 'histo' 50.0 'female'
#  'neck' 1]
# ['HAM_0001385' 'ISIC_0033770' 'Benign Keratosis' 'histo' 50.0 'female'
#  'neck' 1]
# ['HAM_0003845' 'ISIC_0032829' 'Benign Keratosis' 'histo' 40.0 'female'
#  'trunk' 1]
# ['HAM_0003845' 'ISIC_0033601' 'Benign Keratosis' 'histo' 40.0 'female'
#  'trunk' 1]
# ['HAM_0003978' 'ISIC_0033284' 'Benign Keratosis' 'histo' 80.0 'male'
#  'trunk' 1]
# ['HAM_0003978' 'ISIC_0033908' 'Benign Keratosis' 'histo' 80.0 'male'
#  'trunk' 1]
# ['HAM_0005258' 'ISIC_0033400' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0005258' 'ISIC_0033677' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0005258' 'ISIC_0033262' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0000802' 'ISIC_0033437' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0006801' 'ISIC_0032688' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0000802' 'ISIC_0033195' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0000802' 'ISIC_0032553' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0006801' 'ISIC_0033252' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0006801' 'ISIC_0032570' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0007625' 'ISIC_0033736' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0007625' 'ISIC_0033378' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0002008' 'ISIC_0033379' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0002008' 'ISIC_0033438' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0002008' 'ISIC_0032983' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0002008' 'ISIC_0034024' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0004975' 'ISIC_0033778' 'Benign Keratosis' 'histo' 85.0 'male'
#  'chest' 1]
# ['HAM_0004975' 'ISIC_0032863' 'Benign Keratosis' 'histo' 85.0 'male'
#  'chest' 1]
# ['HAM_0004975' 'ISIC_0034168' 'Benign Keratosis' 'histo' 85.0 'male'
#  'chest' 1]
# ['HAM_0004442' 'ISIC_0033582' 'Benign Keratosis' 'histo' 85.0 'male'
#  'trunk' 1]
# ['HAM_0004442' 'ISIC_0033576' 'Benign Keratosis' 'histo' 85.0 'male'
#  'trunk' 1]
# ['HAM_0007384' 'ISIC_0033410' 'Benign Keratosis' 'histo' 65.0 'female'
#  'face' 1]
# ['HAM_0007384' 'ISIC_0032725' 'Benign Keratosis' 'histo' 65.0 'female'
#  'face' 1]
# ['HAM_0000516' 'ISIC_0033952' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0004255' 'ISIC_0033264' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0002327' 'ISIC_0033606' 'Benign Keratosis' 'histo' 60.0 'female'
#  'neck' 1]
# ['HAM_0002327' 'ISIC_0034103' 'Benign Keratosis' 'histo' 60.0 'female'
#  'neck' 1]
# ['HAM_0002327' 'ISIC_0032883' 'Benign Keratosis' 'histo' 60.0 'female'
#  'neck' 1]
# ['HAM_0002928' 'ISIC_0032665' 'Benign Keratosis' 'histo' 80.0 'male'
#  'trunk' 1]
# ['HAM_0002928' 'ISIC_0033130' 'Benign Keratosis' 'histo' 80.0 'male'
#  'trunk' 1]
# ['HAM_0001354' 'ISIC_0033321' 'Benign Keratosis' 'histo' 65.0 'male'
#  'lower extremity' 1]
# ['HAM_0000805' 'ISIC_0034189' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0000805' 'ISIC_0033306' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0000527' 'ISIC_0032757' 'Benign Keratosis' 'histo' 45.0 'female'
#  'face' 1]
# ['HAM_0000527' 'ISIC_0032508' 'Benign Keratosis' 'histo' 45.0 'female'
#  'face' 1]
# ['HAM_0000527' 'ISIC_0034201' 'Benign Keratosis' 'histo' 45.0 'female'
#  'face' 1]
# ['HAM_0001954' 'ISIC_0032776' 'Benign Keratosis' 'histo' 55.0 'male'
#  'trunk' 1]
# ['HAM_0001954' 'ISIC_0033828' 'Benign Keratosis' 'histo' 55.0 'male'
#  'trunk' 1]
# ['HAM_0001858' 'ISIC_0033235' 'Benign Keratosis' 'histo' 85.0 'male'
#  'scalp' 1]
# ['HAM_0001858' 'ISIC_0026085' 'Benign Keratosis' 'histo' 85.0 'male'
#  'scalp' 1]
# ['HAM_0000087' 'ISIC_0034070' 'Benign Keratosis' 'histo' 45.0 'male'
#  'upper extremity' 1]
# ['HAM_0000087' 'ISIC_0033709' 'Benign Keratosis' 'histo' 45.0 'male'
#  'upper extremity' 1]
# ['HAM_0000581' 'ISIC_0032826' 'Benign Keratosis' 'histo' 40.0 'female'
#  'chest' 1]
# ['HAM_0000581' 'ISIC_0034115' 'Benign Keratosis' 'histo' 40.0 'female'
#  'chest' 1]
# ['HAM_0002894' 'ISIC_0033776' 'Benign Keratosis' 'histo' 40.0 'female'
#  'abdomen' 1]
# ['HAM_0002894' 'ISIC_0033056' 'Benign Keratosis' 'histo' 40.0 'female'
#  'abdomen' 1]
# ['HAM_0003265' 'ISIC_0025180' 'Benign Keratosis' 'histo' 35.0 'female'
#  'chest' 1]
# ['HAM_0003265' 'ISIC_0026107' 'Benign Keratosis' 'histo' 35.0 'female'
#  'chest' 1]
# ['HAM_0004458' 'ISIC_0033853' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0004458' 'ISIC_0033453' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0004458' 'ISIC_0034126' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0003050' 'ISIC_0033744' 'Benign Keratosis' 'histo' 70.0 'male'
#  'face' 1]
# ['HAM_0003050' 'ISIC_0033659' 'Benign Keratosis' 'histo' 70.0 'male'
#  'face' 1]
# ['HAM_0003927' 'ISIC_0032567' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0003927' 'ISIC_0033088' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0003927' 'ISIC_0032756' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0000790' 'ISIC_0032654' 'Benign Keratosis' 'histo' 75.0 'male'
#  'face' 1]
# ['HAM_0000790' 'ISIC_0032576' 'Benign Keratosis' 'histo' 75.0 'male'
#  'face' 1]
# ['HAM_0004091' 'ISIC_0033587' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0004091' 'ISIC_0032675' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0003162' 'ISIC_0032997' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0003162' 'ISIC_0033529' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0001855' 'ISIC_0033581' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0001855' 'ISIC_0033913' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0005131' 'ISIC_0034235' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0005131' 'ISIC_0034007' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0002372' 'ISIC_0034303' 'Benign Keratosis' 'histo' 65.0 'male'
#  'neck' 1]
# ['HAM_0002372' 'ISIC_0034031' 'Benign Keratosis' 'histo' 65.0 'male'
#  'neck' 1]
# ['HAM_0002372' 'ISIC_0033124' 'Benign Keratosis' 'histo' 65.0 'male'
#  'neck' 1]
# ['HAM_0003659' 'ISIC_0033449' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0003659' 'ISIC_0033676' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0007341' 'ISIC_0032898' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0007341' 'ISIC_0033488' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0007341' 'ISIC_0033758' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0001608' 'ISIC_0028792' 'Benign Keratosis' 'histo' 65.0 'male'
#  'face' 1]
# ['HAM_0001384' 'ISIC_0033397' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0001384' 'ISIC_0033414' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0001384' 'ISIC_0034113' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0006281' 'ISIC_0033507' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0006281' 'ISIC_0033791' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0004555' 'ISIC_0034259' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0004555' 'ISIC_0033446' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0004555' 'ISIC_0033200' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0004029' 'ISIC_0029472' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0004029' 'ISIC_0029682' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0006018' 'ISIC_0033642' 'Benign Keratosis' 'histo' 75.0 'male'
#  'trunk' 1]
# ['HAM_0006018' 'ISIC_0033486' 'Benign Keratosis' 'histo' 75.0 'male'
#  'trunk' 1]
# ['HAM_0007402' 'ISIC_0034003' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0007402' 'ISIC_0033079' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0001309' 'ISIC_0033629' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0001309' 'ISIC_0034037' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0001309' 'ISIC_0032876' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0001837' 'ISIC_0033635' 'Benign Keratosis' 'histo' 80.0 'male'
#  'trunk' 1]
# ['HAM_0001837' 'ISIC_0033868' 'Benign Keratosis' 'histo' 80.0 'male'
#  'trunk' 1]
# ['HAM_0004406' 'ISIC_0034125' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0004406' 'ISIC_0033060' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0004373' 'ISIC_0029014' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0002455' 'ISIC_0032099' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0002050' 'ISIC_0032215' 'Benign Keratosis' 'histo' 40.0 'male'
#  'scalp' 1]
# ['HAM_0004807' 'ISIC_0030124' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0004491' 'ISIC_0025157' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0001927' 'ISIC_0029600' 'Benign Keratosis' 'histo' 85.0 'female'
#  'abdomen' 1]
# ['HAM_0005862' 'ISIC_0031376' 'Benign Keratosis' 'histo' 65.0 'female'
#  'face' 1]
# ['HAM_0004748' 'ISIC_0027513' 'Benign Keratosis' 'histo' 55.0 'male'
#  'upper extremity' 1]
# ['HAM_0002810' 'ISIC_0031876' 'Benign Keratosis' 'histo' 70.0 'female'
#  'chest' 1]
# ['HAM_0007431' 'ISIC_0031620' 'Benign Keratosis' 'histo' 50.0 'male'
#  'face' 1]
# ['HAM_0002810' 'ISIC_0030542' 'Benign Keratosis' 'histo' 70.0 'female'
#  'chest' 1]
# ['HAM_0000113' 'ISIC_0029548' 'Benign Keratosis' 'histo' 75.0 'female'
#  'hand' 1]
# ['HAM_0000113' 'ISIC_0027989' 'Benign Keratosis' 'histo' 75.0 'female'
#  'hand' 1]
# ['HAM_0000308' 'ISIC_0025136' 'Benign Keratosis' 'histo' 55.0 'female'
#  'abdomen' 1]
# ['HAM_0004958' 'ISIC_0027652' 'Benign Keratosis' 'histo' 70.0 'male'
#  'neck' 1]
# ['HAM_0001738' 'ISIC_0027218' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0004141' 'ISIC_0030705' 'Benign Keratosis' 'histo' 50.0 'female'
#  'back' 1]
# ['HAM_0006697' 'ISIC_0030272' 'Benign Keratosis' 'histo' 50.0 'female'
#  'trunk' 1]
# ['HAM_0003090' 'ISIC_0028020' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0002691' 'ISIC_0031345' 'Benign Keratosis' 'histo' 80.0 'female'
#  'hand' 1]
# ['HAM_0006630' 'ISIC_0032063' 'Benign Keratosis' 'histo' 50.0 'male'
#  'trunk' 1]
# ['HAM_0002184' 'ISIC_0032325' 'Benign Keratosis' 'histo' 70.0 'male'
#  'scalp' 1]
# ['HAM_0007220' 'ISIC_0025867' 'Benign Keratosis' 'histo' 60.0 'male'
#  'lower extremity' 1]
# ['HAM_0006128' 'ISIC_0028701' 'Benign Keratosis' 'histo' 55.0 'female'
#  'lower extremity' 1]
# ['HAM_0001562' 'ISIC_0027713' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0005891' 'ISIC_0026060' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0002529' 'ISIC_0026298' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0005440' 'ISIC_0027139' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0003800' 'ISIC_0026623' 'Benign Keratosis' 'histo' 70.0 'male'
#  'upper extremity' 1]
# ['HAM_0007100' 'ISIC_0031989' 'Benign Keratosis' 'histo' 50.0 'male'
#  'face' 1]
# ['HAM_0004566' 'ISIC_0029394' 'Benign Keratosis' 'histo' 55.0 'female'
#  'lower extremity' 1]
# ['HAM_0003791' 'ISIC_0026893' 'Benign Keratosis' 'histo' 65.0 'male'
#  'lower extremity' 1]
# ['HAM_0002827' 'ISIC_0025777' 'Benign Keratosis' 'histo' 80.0 'male'
#  'lower extremity' 1]
# ['HAM_0006325' 'ISIC_0027739' 'Benign Keratosis' 'histo' 50.0 'male'
#  'lower extremity' 1]
# ['HAM_0004114' 'ISIC_0026844' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0005790' 'ISIC_0024672' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0005465' 'ISIC_0026827' 'Benign Keratosis' 'histo' 60.0 'female'
#  'back' 1]
# ['HAM_0004677' 'ISIC_0027680' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0000582' 'ISIC_0025885' 'Benign Keratosis' 'histo' 85.0 'male'
#  'lower extremity' 1]
# ['HAM_0005915' 'ISIC_0025656' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0003293' 'ISIC_0029010' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0001995' 'ISIC_0024581' 'Benign Keratosis' 'histo' 40.0 'male'
#  'lower extremity' 1]
# ['HAM_0004947' 'ISIC_0029003' 'Benign Keratosis' 'histo' 75.0 'male'
#  'abdomen' 1]
# ['HAM_0004947' 'ISIC_0024711' 'Benign Keratosis' 'histo' 75.0 'male'
#  'abdomen' 1]
# ['HAM_0002839' 'ISIC_0032280' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0002839' 'ISIC_0025982' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0001055' 'ISIC_0028120' 'Benign Keratosis' 'histo' 65.0 'male'
#  'lower extremity' 1]
# ['HAM_0005498' 'ISIC_0032335' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0003000' 'ISIC_0025326' 'Benign Keratosis' 'histo' 50.0 'female'
#  'upper extremity' 1]
# ['HAM_0004690' 'ISIC_0027374' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0005693' 'ISIC_0027781' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0007439' 'ISIC_0024890' 'Benign Keratosis' 'histo' 60.0 'female'
#  'upper extremity' 1]
# ['HAM_0006190' 'ISIC_0025507' 'Benign Keratosis' 'histo' 65.0 'female'
#  'lower extremity' 1]
# ['HAM_0007260' 'ISIC_0028336' 'Benign Keratosis' 'histo' 60.0 'male'
#  'chest' 1]
# ['HAM_0001362' 'ISIC_0025838' 'Benign Keratosis' 'histo' 75.0 'male'
#  'chest' 1]
# ['HAM_0007332' 'ISIC_0027780' 'Benign Keratosis' 'histo' 70.0 'male'
#  'lower extremity' 1]
# ['HAM_0000236' 'ISIC_0024592' 'Benign Keratosis' 'histo' 40.0 'female'
#  'abdomen' 1]
# ['HAM_0003613' 'ISIC_0030118' 'Benign Keratosis' 'histo' 80.0 'female'
#  'back' 1]
# ['HAM_0001435' 'ISIC_0028970' 'Benign Keratosis' 'histo' 65.0 'female'
#  'hand' 1]
# ['HAM_0002078' 'ISIC_0027042' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0006769' 'ISIC_0030721' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0006122' 'ISIC_0031556' 'Benign Keratosis' 'histo' 60.0 'male'
#  'scalp' 1]
# ['HAM_0007296' 'ISIC_0027068' 'Benign Keratosis' 'histo' 65.0 'female'
#  'upper extremity' 1]
# ['HAM_0006143' 'ISIC_0032168' 'Benign Keratosis' 'histo' 60.0 'female'
#  'upper extremity' 1]
# ['HAM_0006350' 'ISIC_0031130' 'Benign Keratosis' 'histo' 50.0 'female'
#  'chest' 1]
# ['HAM_0003752' 'ISIC_0028308' 'Benign Keratosis' 'histo' 50.0 'female'
#  'chest' 1]
# ['HAM_0003868' 'ISIC_0024708' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0000122' 'ISIC_0028354' 'Benign Keratosis' 'histo' 50.0 'male'
#  'face' 1]
# ['HAM_0000364' 'ISIC_0024505' 'Benign Keratosis' 'histo' 40.0 'female'
#  'face' 1]
# ['HAM_0004382' 'ISIC_0025743' 'Benign Keratosis' 'histo' 85.0 'male'
#  'face' 1]
# ['HAM_0000745' 'ISIC_0027796' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0007621' 'ISIC_0024626' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0007621' 'ISIC_0031321' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0002988' 'ISIC_0025337' 'Benign Keratosis' 'histo' 35.0 'male'
#  'face' 1]
# ['HAM_0003140' 'ISIC_0027037' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0002121' 'ISIC_0032486' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0005157' 'ISIC_0029340' 'Benign Keratosis' 'histo' 40.0 'male'
#  'chest' 1]
# ['HAM_0006987' 'ISIC_0027649' 'Benign Keratosis' 'histo' 85.0 'female'
#  'upper extremity' 1]
# ['HAM_0007529' 'ISIC_0026607' 'Benign Keratosis' 'histo' 50.0 'male'
#  'chest' 1]
# ['HAM_0005865' 'ISIC_0030731' 'Benign Keratosis' 'histo' 70.0 'male'
#  'chest' 1]
# ['HAM_0002392' 'ISIC_0028233' 'Benign Keratosis' 'histo' 55.0 'male'
#  'face' 1]
# ['HAM_0003014' 'ISIC_0031542' 'Benign Keratosis' 'histo' 45.0 'male'
#  'upper extremity' 1]
# ['HAM_0003076' 'ISIC_0029062' 'Benign Keratosis' 'histo' 65.0 'female'
#  'face' 1]
# ['HAM_0005325' 'ISIC_0024971' 'Benign Keratosis' 'histo' 50.0 'male'
#  'neck' 1]
# ['HAM_0005260' 'ISIC_0025485' 'Benign Keratosis' 'histo' 65.0 'male'
#  'scalp' 1]
# ['HAM_0003689' 'ISIC_0025874' 'Benign Keratosis' 'histo' 80.0 'male'
#  'upper extremity' 1]
# ['HAM_0000884' 'ISIC_0026728' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0002335' 'ISIC_0031812' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0002335' 'ISIC_0030465' 'Benign Keratosis' 'histo' 85.0 'male'
#  'upper extremity' 1]
# ['HAM_0004274' 'ISIC_0025842' 'Benign Keratosis' 'histo' 60.0 'female'
#  'neck' 1]
# ['HAM_0004500' 'ISIC_0025032' 'Benign Keratosis' 'histo' 75.0 'female'
#  'back' 1]
# ['HAM_0003089' 'ISIC_0030706' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0002199' 'ISIC_0029522' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0004928' 'ISIC_0031424' 'Benign Keratosis' 'histo' 65.0 'male'
#  'neck' 1]
# ['HAM_0004928' 'ISIC_0029770' 'Benign Keratosis' 'histo' 65.0 'male'
#  'neck' 1]
# ['HAM_0004917' 'ISIC_0026301' 'Benign Keratosis' 'histo' 65.0 'male'
#  'lower extremity' 1]
# ['HAM_0004917' 'ISIC_0030227' 'Benign Keratosis' 'histo' 65.0 'male'
#  'lower extremity' 1]
# ['HAM_0004501' 'ISIC_0028856' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0002585' 'ISIC_0027026' 'Benign Keratosis' 'histo' 85.0 'female'
#  'neck' 1]
# ['HAM_0000050' 'ISIC_0030095' 'Benign Keratosis' 'histo' 60.0 'male'
#  'upper extremity' 1]
# ['HAM_0000050' 'ISIC_0031394' 'Benign Keratosis' 'histo' 60.0 'male'
#  'upper extremity' 1]
# ['HAM_0005674' 'ISIC_0031060' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0001546' 'ISIC_0027584' 'Benign Keratosis' 'histo' 45.0 'male'
#  'chest' 1]
# ['HAM_0003768' 'ISIC_0026634' 'Benign Keratosis' 'histo' 80.0 'male'
#  'upper extremity' 1]
# ['HAM_0003830' 'ISIC_0028496' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0000245' 'ISIC_0027454' 'Benign Keratosis' 'histo' 75.0 'female'
#  'back' 1]
# ['HAM_0002169' 'ISIC_0031593' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0001389' 'ISIC_0026775' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0003835' 'ISIC_0024412' 'Benign Keratosis' 'histo' 35.0 'male'
#  'back' 1]
# ['HAM_0006294' 'ISIC_0032348' 'Benign Keratosis' 'histo' 75.0 'female'
#  'chest' 1]
# ['HAM_0006541' 'ISIC_0024883' 'Benign Keratosis' 'histo' 35.0 'female'
#  'lower extremity' 1]
# ['HAM_0006472' 'ISIC_0027394' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0000844' 'ISIC_0024773' 'Benign Keratosis' 'histo' 70.0 'male'
#  'lower extremity' 1]
# ['HAM_0003913' 'ISIC_0027295' 'Benign Keratosis' 'histo' 60.0 'male'
#  'hand' 1]
# ['HAM_0002169' 'ISIC_0032200' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0004131' 'ISIC_0025583' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0000933' 'ISIC_0024358' 'Benign Keratosis' 'histo' 60.0 'female'
#  'back' 1]
# ['HAM_0000847' 'ISIC_0030744' 'Benign Keratosis' 'histo' 85.0 'female'
#  'lower extremity' 1]
# ['HAM_0000933' 'ISIC_0027771' 'Benign Keratosis' 'histo' 60.0 'female'
#  'back' 1]
# ['HAM_0003069' 'ISIC_0027344' 'Benign Keratosis' 'histo' 70.0 'male'
#  'lower extremity' 1]
# ['HAM_0004491' 'ISIC_0028846' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0004491' 'ISIC_0026159' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0005022' 'ISIC_0027367' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0006065' 'ISIC_0028952' 'Benign Keratosis' 'histo' 40.0 'female'
#  'lower extremity' 1]
# ['HAM_0003420' 'ISIC_0024748' 'Benign Keratosis' 'histo' 45.0 'male'
#  'abdomen' 1]
# ['HAM_0007521' 'ISIC_0032156' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0006513' 'ISIC_0030783' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0005074' 'ISIC_0028200' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0001788' 'ISIC_0029100' 'Benign Keratosis' 'histo' 65.0 'male'
#  'chest' 1]
# ['HAM_0002933' 'ISIC_0027287' 'Benign Keratosis' 'histo' 55.0 'female'
#  'chest' 1]
# ['HAM_0002933' 'ISIC_0024494' 'Benign Keratosis' 'histo' 55.0 'female'
#  'chest' 1]
# ['HAM_0000198' 'ISIC_0026923' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0000243' 'ISIC_0024445' 'Benign Keratosis' 'histo' 55.0 'male'
#  'lower extremity' 1]
# ['HAM_0004945' 'ISIC_0029358' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0004945' 'ISIC_0031766' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0004945' 'ISIC_0030258' 'Benign Keratosis' 'histo' 85.0 'male'
#  'back' 1]
# ['HAM_0001896' 'ISIC_0030203' 'Benign Keratosis' 'histo' 50.0 'male'
#  'back' 1]
# ['HAM_0007513' 'ISIC_0025297' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0007513' 'ISIC_0024676' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0002306' 'ISIC_0027606' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0000110' 'ISIC_0025703' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0001947' 'ISIC_0032051' 'Benign Keratosis' 'histo' 50.0 'male'
#  'chest' 1]
# ['HAM_0002902' 'ISIC_0026443' 'Benign Keratosis' 'histo' 80.0 'female'
#  'lower extremity' 1]
# ['HAM_0002769' 'ISIC_0032481' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0003140' 'ISIC_0030459' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0003140' 'ISIC_0029776' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0003152' 'ISIC_0027996' 'Benign Keratosis' 'histo' 40.0 'female'
#  'face' 1]
# ['HAM_0005514' 'ISIC_0024453' 'Benign Keratosis' 'histo' 65.0 'female'
#  'face' 1]
# ['HAM_0005546' 'ISIC_0029519' 'Benign Keratosis' 'histo' 60.0 'male'
#  'back' 1]
# ['HAM_0004259' 'ISIC_0026644' 'Benign Keratosis' 'histo' 60.0 'female'
#  'neck' 1]
# ['HAM_0001325' 'ISIC_0030522' 'Benign Keratosis' 'histo' 70.0 'male'
#  'scalp' 1]
# ['HAM_0000298' 'ISIC_0029051' 'Benign Keratosis' 'histo' 65.0 'male'
#  'lower extremity' 1]
# ['HAM_0004545' 'ISIC_0025985' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0007110' 'ISIC_0026861' 'Benign Keratosis' 'histo' 85.0 'female'
#  'face' 1]
# ['HAM_0007232' 'ISIC_0025830' 'Benign Keratosis' 'histo' 80.0 'male'
#  'back' 1]
# ['HAM_0007261' 'ISIC_0031686' 'Benign Keratosis' 'histo' 65.0 'male'
#  'face' 1]
# ['HAM_0003152' 'ISIC_0030208' 'Benign Keratosis' 'histo' 40.0 'female'
#  'face' 1]
# ['HAM_0003452' 'ISIC_0032006' 'Benign Keratosis' 'histo' 75.0 'male'
#  'chest' 1]
# ['HAM_0003452' 'ISIC_0028920' 'Benign Keratosis' 'histo' 75.0 'male'
#  'chest' 1]
# ['HAM_0000782' 'ISIC_0030723' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0001493' 'ISIC_0032373' 'Benign Keratosis' 'histo' 70.0 'female'
#  'chest' 1]
# ['HAM_0002301' 'ISIC_0028555' 'Benign Keratosis' 'histo' 50.0 'male'
#  'scalp' 1]
# ['HAM_0002301' 'ISIC_0029568' 'Benign Keratosis' 'histo' 50.0 'male'
#  'scalp' 1]
# ['HAM_0002316' 'ISIC_0029217' 'Benign Keratosis' 'histo' 35.0 'male'
#  'face' 1]
# ['HAM_0005935' 'ISIC_0028254' 'Benign Keratosis' 'histo' 70.0 'female'
#  'chest' 1]
# ['HAM_0004377' 'ISIC_0030561' 'Benign Keratosis' 'histo' 40.0 'female'
#  'foot' 1]
# ['HAM_0004506' 'ISIC_0027320' 'Benign Keratosis' 'histo' 85.0 'female'
#  'neck' 1]
# ['HAM_0004249' 'ISIC_0031591' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0006123' 'ISIC_0025275' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0006123' 'ISIC_0026606' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0006123' 'ISIC_0025986' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0003179' 'ISIC_0029108' 'Benign Keratosis' 'histo' 35.0 'female'
#  'face' 1]
# ['HAM_0004889' 'ISIC_0028511' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0004889' 'ISIC_0026714' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0004889' 'ISIC_0028473' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0000898' 'ISIC_0025529' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0007332' 'ISIC_0026481' 'Benign Keratosis' 'histo' 70.0 'male'
#  'lower extremity' 1]
# ['HAM_0007563' 'ISIC_0025075' 'Benign Keratosis' 'histo' 60.0 'male'
#  'upper extremity' 1]
# ['HAM_0004105' 'ISIC_0030007' 'Benign Keratosis' 'histo' 85.0 'female'
#  'hand' 1]
# ['HAM_0005606' 'ISIC_0025928' 'Benign Keratosis' 'histo' 85.0 'female'
#  'back' 1]
# ['HAM_0005558' 'ISIC_0030812' 'Benign Keratosis' 'histo' 85.0 'male'
#  'face' 1]
# ['HAM_0005558' 'ISIC_0029802' 'Benign Keratosis' 'histo' 85.0 'male'
#  'face' 1]
# ['HAM_0006170' 'ISIC_0027969' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0006128' 'ISIC_0031770' 'Benign Keratosis' 'histo' 55.0 'female'
#  'lower extremity' 1]
# ['HAM_0006170' 'ISIC_0029557' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0000992' 'ISIC_0026661' 'Benign Keratosis' 'histo' 65.0 'female'
#  'chest' 1]
# ['HAM_0006170' 'ISIC_0032123' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0004691' 'ISIC_0025805' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0004691' 'ISIC_0029166' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0005883' 'ISIC_0026018' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0006563' 'ISIC_0026477' 'Benign Keratosis' 'histo' 50.0 'female'
#  'lower extremity' 1]
# ['HAM_0001562' 'ISIC_0029789' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0004400' 'ISIC_0030026' 'Benign Keratosis' 'histo' 75.0 'female'
#  'face' 1]
# ['HAM_0004883' 'ISIC_0031851' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0004883' 'ISIC_0030436' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0005527' 'ISIC_0031819' 'Benign Keratosis' 'histo' 50.0 'male'
#  'unknown' 1]
# ['HAM_0002535' 'ISIC_0027754' 'Benign Keratosis' 'histo' 50.0 'female'
#  'face' 1]
# ['HAM_0000770' 'ISIC_0024741' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0005157' 'ISIC_0026286' 'Benign Keratosis' 'histo' 40.0 'male'
#  'chest' 1]
# ['HAM_0005157' 'ISIC_0024880' 'Benign Keratosis' 'histo' 40.0 'male'
#  'chest' 1]
# ['HAM_0004988' 'ISIC_0025659' 'Benign Keratosis' 'histo' 75.0 'male'
#  'lower extremity' 1]
# ['HAM_0005935' 'ISIC_0026679' 'Benign Keratosis' 'histo' 70.0 'female'
#  'chest' 1]
# ['HAM_0007573' 'ISIC_0029420' 'Benign Keratosis' 'histo' 35.0 'male'
#  'back' 1]
# ['HAM_0000744' 'ISIC_0032230' 'Benign Keratosis' 'histo' 70.0 'male'
#  'face' 1]
# ['HAM_0000744' 'ISIC_0029525' 'Benign Keratosis' 'histo' 70.0 'male'
#  'face' 1]
# ['HAM_0000744' 'ISIC_0029474' 'Benign Keratosis' 'histo' 70.0 'male'
#  'face' 1]
# ['HAM_0000202' 'ISIC_0027219' 'Benign Keratosis' 'histo' 50.0 'male'
#  'face' 1]
# ['HAM_0001057' 'ISIC_0032045' 'Benign Keratosis' 'histo' 75.0 'female'
#  'back' 1]
# ['HAM_0001057' 'ISIC_0024381' 'Benign Keratosis' 'histo' 75.0 'female'
#  'back' 1]
# ['HAM_0001597' 'ISIC_0026265' 'Benign Keratosis' 'histo' 50.0 'male'
#  'back' 1]
# ['HAM_0001597' 'ISIC_0024426' 'Benign Keratosis' 'histo' 50.0 'male'
#  'back' 1]
# ['HAM_0001603' 'ISIC_0031016' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0006945' 'ISIC_0026044' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0005596' 'ISIC_0027706' 'Benign Keratosis' 'histo' 30.0 'female'
#  'face' 1]
# ['HAM_0005420' 'ISIC_0024740' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0003840' 'ISIC_0027801' 'Benign Keratosis' 'histo' 55.0 'female'
#  'face' 1]
# ['HAM_0005146' 'ISIC_0030346' 'Benign Keratosis' 'histo' 60.0 'male'
#  'face' 1]
# ['HAM_0005146' 'ISIC_0026526' 'Benign Keratosis' 'histo' 60.0 'male'
#  'face' 1]
# ['HAM_0006580' 'ISIC_0025376' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0003899' 'ISIC_0029991' 'Benign Keratosis' 'histo' 75.0 'male'
#  'back' 1]
# ['HAM_0005125' 'ISIC_0024726' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0003476' 'ISIC_0029603' 'Benign Keratosis' 'histo' 70.0 'male'
#  'lower extremity' 1]
# ['HAM_0001510' 'ISIC_0028100' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0001536' 'ISIC_0031449' 'Benign Keratosis' 'histo' 45.0 'female'
#  'face' 1]
# ['HAM_0001536' 'ISIC_0026842' 'Benign Keratosis' 'histo' 45.0 'female'
#  'face' 1]
# ['HAM_0001539' 'ISIC_0026444' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0001605' 'ISIC_0024422' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0005420' 'ISIC_0030649' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0005591' 'ISIC_0025746' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0005420' 'ISIC_0032043' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0005672' 'ISIC_0030806' 'Benign Keratosis' 'histo' 50.0 'female'
#  'face' 1]
# ['HAM_0005672' 'ISIC_0028388' 'Benign Keratosis' 'histo' 50.0 'female'
#  'face' 1]
# ['HAM_0005708' 'ISIC_0029791' 'Benign Keratosis' 'histo' 70.0 'female'
#  'upper extremity' 1]
# ['HAM_0001273' 'ISIC_0027806' 'Benign Keratosis' 'histo' 80.0 'female'
#  'back' 1]
# ['HAM_0001245' 'ISIC_0031168' 'Benign Keratosis' 'histo' 60.0 'male'
#  'chest' 1]
# ['HAM_0001245' 'ISIC_0025575' 'Benign Keratosis' 'histo' 60.0 'male'
#  'chest' 1]
# ['HAM_0005728' 'ISIC_0025781' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0005790' 'ISIC_0024547' 'Benign Keratosis' 'histo' 65.0 'male'
#  'back' 1]
# ['HAM_0005869' 'ISIC_0029249' 'Benign Keratosis' 'histo' 75.0 'female'
#  'chest' 1]
# ['HAM_0005869' 'ISIC_0030822' 'Benign Keratosis' 'histo' 75.0 'female'
#  'chest' 1]
# ['HAM_0005968' 'ISIC_0024758' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0001226' 'ISIC_0030636' 'Benign Keratosis' 'histo' 70.0 'female'
#  'back' 1]
# ['HAM_0003766' 'ISIC_0027760' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0003766' 'ISIC_0026538' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0003856' 'ISIC_0024760' 'Benign Keratosis' 'histo' 50.0 'male'
#  'upper extremity' 1]
# ['HAM_0001809' 'ISIC_0029897' 'Benign Keratosis' 'histo' 80.0 'female'
#  'unknown' 1]
# ['HAM_0001815' 'ISIC_0024970' 'Benign Keratosis' 'histo' 85.0 'male'
#  'chest' 1]
# ['HAM_0007018' 'ISIC_0027006' 'Benign Keratosis' 'histo' 75.0 'male'
#  'chest' 1]
# ['HAM_0007018' 'ISIC_0029596' 'Benign Keratosis' 'histo' 75.0 'male'
#  'chest' 1]
# ['HAM_0007591' 'ISIC_0025351' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0001605' 'ISIC_0028881' 'Benign Keratosis' 'histo' 75.0 'male'
#  'upper extremity' 1]
# ['HAM_0001958' 'ISIC_0029580' 'Benign Keratosis' 'histo' 60.0 'female'
#  'face' 1]
# ['HAM_0001979' 'ISIC_0027527' 'Benign Keratosis' 'histo' 55.0 'male'
#  'face' 1]
# ['HAM_0003476' 'ISIC_0028972' 'Benign Keratosis' 'histo' 70.0 'male'
#  'lower extremity' 1]
# ['HAM_0003943' 'ISIC_0031078' 'Benign Keratosis' 'histo' 80.0 'female'
#  'lower extremity' 1]
# ['HAM_0003943' 'ISIC_0031464' 'Benign Keratosis' 'histo' 80.0 'female'
#  'lower extremity' 1]
# ['HAM_0002879' 'ISIC_0025693' 'Benign Keratosis' 'histo' 80.0 'male'
#  'scalp' 1]
# ['HAM_0003275' 'ISIC_0032116' 'Benign Keratosis' 'histo' 75.0 'female'
#  'chest' 1]
# ['HAM_0000207' 'ISIC_0027451' 'Benign Keratosis' 'histo' 75.0 'female'
#  'chest' 1]
# ['HAM_0003279' 'ISIC_0030329' 'Benign Keratosis' 'histo' 70.0 'female'
#  'lower extremity' 1]
# ['HAM_0002592' 'ISIC_0029311' 'Benign Keratosis' 'histo' 60.0 'female'
#  'lower extremity' 1]
# ['HAM_0004545' 'ISIC_0026849' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0004570' 'ISIC_0030396' 'Benign Keratosis' 'histo' 50.0 'female'
#  'chest' 1]
# ['HAM_0002058' 'ISIC_0024893' 'Benign Keratosis' 'histo' 65.0 'female'
#  'ear' 1]
# ['HAM_0006827' 'ISIC_0031702' 'Benign Keratosis' 'histo' 70.0 'male'
#  'face' 1]
# ['HAM_0004143' 'ISIC_0029031' 'Benign Keratosis' 'histo' 50.0 'male'
#  'chest' 1]
# ['HAM_0002400' 'ISIC_0024772' 'Benign Keratosis' 'histo' 70.0 'male'
#  'lower extremity' 1]
# ['HAM_0006399' 'ISIC_0026219' 'Benign Keratosis' 'histo' 60.0 'female'
#  'back' 1]
# ['HAM_0000973' 'ISIC_0025222' 'Benign Keratosis' 'histo' 65.0 'female'
#  'face' 1]
# ['HAM_0007603' 'ISIC_0029139' 'Benign Keratosis' 'histo' 60.0 'male'
#  'unknown' 1]
# ['HAM_0004010' 'ISIC_0031061' 'Benign Keratosis' 'histo' 60.0 'male'
#  'back' 1]
# ['HAM_0003943' 'ISIC_0025973' 'Benign Keratosis' 'histo' 80.0 'female'
#  'lower extremity' 1]
# ['HAM_0004050' 'ISIC_0025086' 'Benign Keratosis' 'histo' 75.0 'female'
#  'lower extremity' 1]
# ['HAM_0003605' 'ISIC_0026895' 'Benign Keratosis' 'histo' 55.0 'male'
#  'face' 1]
# ['HAM_0001200' 'ISIC_0025716' 'Benign Keratosis' 'histo' 85.0 'male'
#  'face' 1]
# ['HAM_0000299' 'ISIC_0024471' 'Benign Keratosis' 'histo' 55.0 'male'
#  'upper extremity' 1]
# ['HAM_0000299' 'ISIC_0029878' 'Benign Keratosis' 'histo' 55.0 'male'
#  'upper extremity' 1]
# ['HAM_0002722' 'ISIC_0027991' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0002722' 'ISIC_0031289' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0002722' 'ISIC_0030172' 'Benign Keratosis' 'histo' 55.0 'male'
#  'back' 1]
# ['HAM_0005335' 'ISIC_0025627' 'Benign Keratosis' 'histo' 40.0 'male'
#  'upper extremity' 1]
# ['HAM_0005335' 'ISIC_0031580' 'Benign Keratosis' 'histo' 40.0 'male'
#  'upper extremity' 1]
# ['HAM_0005335' 'ISIC_0028389' 'Benign Keratosis' 'histo' 40.0 'male'
#  'upper extremity' 1]
# ['HAM_0006541' 'ISIC_0025064' 'Benign Keratosis' 'histo' 35.0 'female'
#  'lower extremity' 1]
# ['HAM_0000318' 'ISIC_0028750' 'Benign Keratosis' 'histo' 55.0 'female'
#  'face' 1]
# ['HAM_0000519' 'ISIC_0030758' 'Benign Keratosis' 'histo' 70.0 'male'
#  'neck' 1]
# ['HAM_0005968' 'ISIC_0027355' 'Benign Keratosis' 'histo' 70.0 'female'
#  'face' 1]
# ['HAM_0004801' 'ISIC_0030365' 'Benign Keratosis' 'histo' 50.0 'male'
#  'back' 1]
# ['HAM_0000386' 'ISIC_0026787' 'Benign Keratosis' 'histo' 65.0 'male'
#  'upper extremity' 1]
# ['HAM_0001938' 'ISIC_0026245' 'Benign Keratosis' 'histo' 45.0 'female'
#  'lower extremity' 1]
# ['HAM_0000979' 'ISIC_0028043' 'Benign Keratosis' 'histo' 70.0 'male'
#  'scalp' 1]
# ['HAM_0005913' 'ISIC_0028640' 'Benign Keratosis' 'histo' 70.0 'male'
#  'back' 1]
# ['HAM_0007598' 'ISIC_0026514' 'Benign Keratosis' 'histo' 65.0 'male'
#  'lower extremity' 1]
# ['HAM_0004426' 'ISIC_0026378' 'Benign Keratosis' 'histo' 50.0 'male'
#  'face' 1]
# ['HAM_0006240' 'ISIC_0030188' 'Benign Keratosis' 'histo' 80.0 'male'
#  'upper extremity' 1]
# ['HAM_0001024' 'ISIC_0027192' 'Benign Keratosis' 'histo' 45.0 'male'
#  'face' 1]
# ['HAM_0004125' 'ISIC_0027437' 'Benign Keratosis' 'histo' 65.0 'female'
#  'neck' 1]
# ['HAM_0005049' 'ISIC_0028201' 'Benign Keratosis' 'histo' 80.0 'male'
#  'face' 1]
# ['HAM_0006595' 'ISIC_0028223' 'Benign Keratosis' 'histo' 55.0 'female'
#  'face' 1]
# ['HAM_0001232' 'ISIC_0026614' 'Benign Keratosis' 'histo' 45.0 'male'
#  'chest' 1]
# ['HAM_0001944' 'ISIC_0029810' 'Benign Keratosis' 'histo' 55.0 'female'
#  'ear' 1]
# ['HAM_0000259' 'ISIC_0028550' 'Benign Keratosis' 'histo' 60.0 'male'
#  'back' 1]
# ['HAM_0000259' 'ISIC_0024477' 'Benign Keratosis' 'histo' 60.0 'male'
#  'back' 1]
# ...
#  'hand' 2]
# ['HAM_0002070' 'ISIC_0028659' "Bowen's disease" 'histo' 70.0 'female'
#  'upper extremity' 2]
# ['HAM_0001178' 'ISIC_0031570' "Bowen's disease" 'histo' 70.0 'female'
#  'back' 2]
# ['HAM_0003380' 'ISIC_0024418' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0003380' 'ISIC_0027343' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0003939' 'ISIC_0027172' "Bowen's disease" 'histo' 75.0 'male' 'face'
#  2]
# ['HAM_0001176' 'ISIC_0028644' "Bowen's disease" 'histo' 65.0 'female'
#  'abdomen' 2]
# ['HAM_0001460' 'ISIC_0025637' "Bowen's disease" 'histo' 75.0 'male' 'face'
#  2]
# ['HAM_0001624' 'ISIC_0032277' "Bowen's disease" 'histo' 85.0 'male'
#  'scalp' 2]
# ['HAM_0002461' 'ISIC_0025953' "Bowen's disease" 'histo' 65.0 'male' 'face'
#  2]
# ['HAM_0003895' 'ISIC_0026203' "Bowen's disease" 'histo' 70.0 'male' 'back'
#  2]
# ['HAM_0005255' 'ISIC_0025811' "Bowen's disease" 'histo' 55.0 'male'
#  'upper extremity' 2]
# ['HAM_0002615' 'ISIC_0033494' "Bowen's disease" 'histo' 70.0 'male'
#  'scalp' 2]
# ['HAM_0003262' 'ISIC_0026212' "Bowen's disease" 'histo' 45.0 'male' 'face'
#  2]
# ['HAM_0002882' 'ISIC_0026014' "Bowen's disease" 'histo' 85.0 'male'
#  'lower extremity' 2]
# ['HAM_0006483' 'ISIC_0032371' "Bowen's disease" 'histo' 75.0 'male'
#  'upper extremity' 2]
# ['HAM_0005459' 'ISIC_0029610' "Bowen's disease" 'histo' 85.0 'male'
#  'upper extremity' 2]
# ['HAM_0002615' 'ISIC_0033413' "Bowen's disease" 'histo' 70.0 'male'
#  'scalp' 2]
# ['HAM_0004609' 'ISIC_0030785' "Bowen's disease" 'histo' 75.0 'male' 'back'
#  2]
# ['HAM_0004809' 'ISIC_0029840' "Bowen's disease" 'histo' 60.0 'male' 'face'
#  2]
# ['HAM_0001786' 'ISIC_0027047' "Bowen's disease" 'histo' 70.0 'male'
#  'upper extremity' 2]
# ['HAM_0005978' 'ISIC_0030143' "Bowen's disease" 'histo' 65.0 'female'
#  'face' 2]
# ['HAM_0004060' 'ISIC_0029210' "Bowen's disease" 'histo' 40.0 'male' 'face'
#  2]
# ['HAM_0002307' 'ISIC_0032154' "Bowen's disease" 'histo' 75.0 'male'
#  'chest' 2]
# ['HAM_0002307' 'ISIC_0026549' "Bowen's disease" 'histo' 75.0 'male'
#  'chest' 2]
# ['HAM_0000982' 'ISIC_0032356' "Bowen's disease" 'histo' 60.0 'male'
#  'lower extremity' 2]
# ['HAM_0000954' 'ISIC_0026100' "Bowen's disease" 'histo' 70.0 'male'
#  'lower extremity' 2]
# ['HAM_0000954' 'ISIC_0029567' "Bowen's disease" 'histo' 70.0 'male'
#  'lower extremity' 2]
# ['HAM_0005650' 'ISIC_0024522' "Bowen's disease" 'histo' 65.0 'male'
#  'lower extremity' 2]
# ['HAM_0005650' 'ISIC_0030387' "Bowen's disease" 'histo' 65.0 'male'
#  'lower extremity' 2]
# ['HAM_0002441' 'ISIC_0031381' "Bowen's disease" 'histo' 80.0 'male'
#  'scalp' 2]
# ['HAM_0000769' 'ISIC_0029851' "Bowen's disease" 'histo' 80.0 'male'
#  'lower extremity' 2]
# ['HAM_0000769' 'ISIC_0029279' "Bowen's disease" 'histo' 80.0 'male'
#  'lower extremity' 2]
# ['HAM_0002646' 'ISIC_0028558' "Bowen's disease" 'histo' 75.0 'male' 'face'
#  2]
# ['HAM_0004568' 'ISIC_0027529' "Bowen's disease" 'histo' 50.0 'male'
#  'upper extremity' 2]
# ['HAM_0004568' 'ISIC_0024463' "Bowen's disease" 'histo' 50.0 'male'
#  'upper extremity' 2]
# ['HAM_0004568' 'ISIC_0028795' "Bowen's disease" 'histo' 50.0 'male'
#  'upper extremity' 2]
# ['HAM_0006879' 'ISIC_0029573' "Bowen's disease" 'histo' 70.0 'male'
#  'lower extremity' 2]
# ['HAM_0005701' 'ISIC_0025350' "Bowen's disease" 'histo' 70.0 'male'
#  'lower extremity' 2]
# ['HAM_0003633' 'ISIC_0030280' "Bowen's disease" 'histo' 70.0 'male'
#  'upper extremity' 2]
# ['HAM_0003157' 'ISIC_0031578' "Bowen's disease" 'histo' 65.0 'male'
#  'upper extremity' 2]
# ['HAM_0005459' 'ISIC_0032397' "Bowen's disease" 'histo' 85.0 'male'
#  'upper extremity' 2]
# ['HAM_0004780' 'ISIC_0030245' "Bowen's disease" 'histo' 75.0 'male'
#  'lower extremity' 2]
# ['HAM_0000688' 'ISIC_0026720' "Bowen's disease" 'histo' 75.0 'male'
#  'lower extremity' 2]
# ['HAM_0000688' 'ISIC_0030487' "Bowen's disease" 'histo' 75.0 'male'
#  'lower extremity' 2]
# ['HAM_0000688' 'ISIC_0032238' "Bowen's disease" 'histo' 75.0 'male'
#  'lower extremity' 2]
# ['HAM_0004439' 'ISIC_0031672' "Bowen's disease" 'histo' 55.0 'female'
#  'face' 2]
# ['HAM_0004439' 'ISIC_0030986' "Bowen's disease" 'histo' 55.0 'female'
#  'face' 2]
# ['HAM_0004439' 'ISIC_0031431' "Bowen's disease" 'histo' 55.0 'female'
#  'face' 2]
# ['HAM_0005480' 'ISIC_0026149' "Bowen's disease" 'histo' 65.0 'male' 'face'
#  2]
# ['HAM_0005480' 'ISIC_0025992' "Bowen's disease" 'histo' 65.0 'male' 'face'
#  2]
# ['HAM_0005459' 'ISIC_0029268' "Bowen's disease" 'histo' 85.0 'male'
#  'upper extremity' 2]
# ['HAM_0003401' 'ISIC_0029598' "Bowen's disease" 'histo' 55.0 'male' 'face'
#  2]
# ['HAM_0003401' 'ISIC_0029002' "Bowen's disease" 'histo' 55.0 'male' 'face'
#  2]
# ['HAM_0002646' 'ISIC_0029781' "Bowen's disease" 'histo' 75.0 'male' 'face'
#  2]
# ['HAM_0001048' 'ISIC_0026525' "Bowen's disease" 'histo' 45.0 'male' 'face'
#  2]
# ['HAM_0001565' 'ISIC_0026709' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0001625' 'ISIC_0028224' "Bowen's disease" 'histo' 40.0 'female'
#  'chest' 2]
# ['HAM_0000462' 'ISIC_0032897' "Bowen's disease" 'histo' 60.0 'female'
#  'lower extremity' 2]
# ['HAM_0000490' 'ISIC_0026206' "Bowen's disease" 'histo' 85.0 'male'
#  'lower extremity' 2]
# ['HAM_0003195' 'ISIC_0026319' "Bowen's disease" 'histo' 80.0 'male'
#  'chest' 2]
# ['HAM_0003195' 'ISIC_0025319' "Bowen's disease" 'histo' 80.0 'male'
#  'chest' 2]
# ['HAM_0004592' 'ISIC_0030730' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0002094' 'ISIC_0030549' "Bowen's disease" 'histo' 50.0 'male'
#  'upper extremity' 2]
# ['HAM_0005231' 'ISIC_0025247' "Bowen's disease" 'histo' 70.0 'male'
#  'lower extremity' 2]
# ['HAM_0005231' 'ISIC_0029043' "Bowen's disease" 'histo' 70.0 'male'
#  'lower extremity' 2]
# ['HAM_0007349' 'ISIC_0026178' "Bowen's disease" 'histo' 60.0 'male' 'back'
#  2]
# ['HAM_0007349' 'ISIC_0032014' "Bowen's disease" 'histo' 60.0 'male' 'back'
#  2]
# ['HAM_0007349' 'ISIC_0027184' "Bowen's disease" 'histo' 60.0 'male' 'back'
#  2]
# ['HAM_0007349' 'ISIC_0029462' "Bowen's disease" 'histo' 60.0 'male' 'back'
#  2]
# ['HAM_0004976' 'ISIC_0028499' "Bowen's disease" 'histo' 80.0 'female'
#  'upper extremity' 2]
# ['HAM_0004976' 'ISIC_0031421' "Bowen's disease" 'histo' 80.0 'female'
#  'upper extremity' 2]
# ['HAM_0007601' 'ISIC_0027447' "Bowen's disease" 'histo' 65.0 'male'
#  'upper extremity' 2]
# ['HAM_0007601' 'ISIC_0027536' "Bowen's disease" 'histo' 65.0 'male'
#  'upper extremity' 2]
# ['HAM_0000005' 'ISIC_0025577' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0000005' 'ISIC_0030591' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0000005' 'ISIC_0024579' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0000005' 'ISIC_0029638' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0003105' 'ISIC_0025029' "Bowen's disease" 'histo' 75.0 'female'
#  'upper extremity' 2]
# ['HAM_0003105' 'ISIC_0026388' "Bowen's disease" 'histo' 75.0 'female'
#  'upper extremity' 2]
# ['HAM_0004992' 'ISIC_0026132' "Bowen's disease" 'histo' 70.0 'male'
#  'chest' 2]
# ['HAM_0001004' 'ISIC_0025790' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0001004' 'ISIC_0024923' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0005020' 'ISIC_0026626' "Bowen's disease" 'histo' 65.0 'female'
#  'face' 2]
# ['HAM_0001219' 'ISIC_0028335' "Bowen's disease" 'histo' 60.0 'female'
#  'lower extremity' 2]
# ['HAM_0005648' 'ISIC_0027580' "Bowen's disease" 'histo' 75.0 'male'
#  'upper extremity' 2]
# ['HAM_0005024' 'ISIC_0025803' "Bowen's disease" 'histo' 80.0 'male' 'face'
#  2]
# ['HAM_0000909' 'ISIC_0026981' "Bowen's disease" 'histo' 55.0 'male'
#  'lower extremity' 2]
# ['HAM_0000909' 'ISIC_0031286' "Bowen's disease" 'histo' 55.0 'male'
#  'lower extremity' 2]
# ['HAM_0005255' 'ISIC_0030158' "Bowen's disease" 'histo' 55.0 'male'
#  'upper extremity' 2]
# ['HAM_0005551' 'ISIC_0029900' "Bowen's disease" 'histo' 60.0 'male' 'face'
#  2]
# ['HAM_0005718' 'ISIC_0029549' "Bowen's disease" 'histo' 70.0 'male' 'back'
#  2]
# ['HAM_0006180' 'ISIC_0026905' "Bowen's disease" 'histo' 70.0 'male'
#  'upper extremity' 2]
# ['HAM_0006220' 'ISIC_0024470' "Bowen's disease" 'histo' 60.0 'male'
#  'upper extremity' 2]
# ['HAM_0006252' 'ISIC_0024646' "Bowen's disease" 'histo' 70.0 'female'
#  'face' 2]
# ['HAM_0006442' 'ISIC_0033000' "Bowen's disease" 'histo' 70.0 'male' 'hand'
#  2]
# ['HAM_0006442' 'ISIC_0033295' "Bowen's disease" 'histo' 70.0 'male' 'hand'
#  2]
# ['HAM_0006524' 'ISIC_0031228' "Bowen's disease" 'histo' 65.0 'male' 'ear'
#  2]
# ['HAM_0006524' 'ISIC_0024763' "Bowen's disease" 'histo' 65.0 'male' 'ear'
#  2]
# ['HAM_0006434' 'ISIC_0028076' "Bowen's disease" 'histo' 60.0 'male'
#  'lower extremity' 2]
# ['HAM_0006434' 'ISIC_0030142' "Bowen's disease" 'histo' 60.0 'male'
#  'lower extremity' 2]
# ['HAM_0006301' 'ISIC_0024468' "Bowen's disease" 'histo' 75.0 'male' 'neck'
#  2]
# ['HAM_0001967' 'ISIC_0025471' "Bowen's disease" 'histo' 85.0 'male'
#  'chest' 2]
# ['HAM_0006301' 'ISIC_0031823' "Bowen's disease" 'histo' 75.0 'male' 'neck'
#  2]
# ['HAM_0006560' 'ISIC_0028063' "Bowen's disease" 'histo' 50.0 'male' 'face'
#  2]
# ['HAM_0004899' 'ISIC_0027930' "Bowen's disease" 'histo' 60.0 'male'
#  'scalp' 2]
# ['HAM_0006560' 'ISIC_0027802' "Bowen's disease" 'histo' 50.0 'male' 'face'
#  2]
# ['HAM_0002954' 'ISIC_0024329' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0006592' 'ISIC_0024925' "Bowen's disease" 'histo' 75.0 'male'
#  'abdomen' 2]
# ['HAM_0000545' 'ISIC_0029460' "Bowen's disease" 'histo' 70.0 'male' 'face'
#  2]
# ['HAM_0003107' 'ISIC_0030844' "Bowen's disease" 'histo' 80.0 'female'
#  'upper extremity' 2]
# ['HAM_0006887' 'ISIC_0031993' "Bowen's disease" 'histo' 45.0 'male' 'face'
#  2]
# ['HAM_0006887' 'ISIC_0029500' "Bowen's disease" 'histo' 45.0 'male' 'face'
#  2]
# ['HAM_0007038' 'ISIC_0032404' "Bowen's disease" 'histo' 70.0 'male' 'face'
#  2]
# ['HAM_0007047' 'ISIC_0025957' "Bowen's disease" 'histo' 60.0 'female'
#  'lower extremity' 2]
# ['HAM_0001277' 'ISIC_0031927' "Bowen's disease" 'histo' 75.0 'male'
#  'chest' 2]
# ['HAM_0004297' 'ISIC_0027550' "Bowen's disease" 'histo' 65.0 'female'
#  'upper extremity' 2]
# ['HAM_0007047' 'ISIC_0025605' "Bowen's disease" 'histo' 60.0 'female'
#  'lower extremity' 2]
# ['HAM_0007088' 'ISIC_0024800' "Bowen's disease" 'histo' 50.0 'male' 'back'
#  2]
# ['HAM_0007199' 'ISIC_0030344' "Bowen's disease" 'histo' 55.0 'female'
#  'face' 2]
# ['HAM_0007623' 'ISIC_0025264' "Bowen's disease" 'histo' 75.0 'male' 'back'
#  2]
# ['HAM_0000356' 'ISIC_0026171' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0007303' 'ISIC_0026457' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0007308' 'ISIC_0026848' "Bowen's disease" 'histo' 55.0 'male' 'face'
#  2]
# ['HAM_0007622' 'ISIC_0027562' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0002551' 'ISIC_0024539' "Bowen's disease" 'histo' 70.0 'male' 'face'
#  2]
# ['HAM_0000832' 'ISIC_0028763' "Bowen's disease" 'histo' 85.0 'male'
#  'upper extremity' 2]
# ['HAM_0000918' 'ISIC_0029133' "Bowen's disease" 'histo' 65.0 'female'
#  'face' 2]
# ['HAM_0003934' 'ISIC_0027767' "Bowen's disease" 'histo' 85.0 'male' 'back'
#  2]
# ['HAM_0001520' 'ISIC_0027294' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0001386' 'ISIC_0027668' "Bowen's disease" 'histo' 60.0 'male'
#  'scalp' 2]
# ['HAM_0001416' 'ISIC_0025427' "Bowen's disease" 'histo' 85.0 'male'
#  'upper extremity' 2]
# ['HAM_0003144' 'ISIC_0032135' "Bowen's disease" 'histo' 65.0 'female'
#  'face' 2]
# ['HAM_0006587' 'ISIC_0025780' "Bowen's disease" 'histo' 70.0 'male' 'face'
#  2]
# ['HAM_0001593' 'ISIC_0028941' "Bowen's disease" 'histo' 70.0 'female'
#  'face' 2]
# ['HAM_0004655' 'ISIC_0030463' "Bowen's disease" 'histo' 70.0 'female'
#  'face' 2]
# ['HAM_0002699' 'ISIC_0029827' "Bowen's disease" 'histo' 60.0 'male' 'back'
#  2]
# ['HAM_0001023' 'ISIC_0026468' "Bowen's disease" 'histo' 50.0 'male' 'hand'
#  2]
# ['HAM_0005228' 'ISIC_0026702' "Bowen's disease" 'histo' 80.0 'female'
#  'face' 2]
# ['HAM_0004033' 'ISIC_0027452' "Bowen's disease" 'histo' 70.0 'male'
#  'upper extremity' 2]
# ['HAM_0001903' 'ISIC_0026984' "Bowen's disease" 'histo' 50.0 'male' 'face'
#  2]
# ['HAM_0001302' 'ISIC_0032206' "Bowen's disease" 'histo' 50.0 'male' 'neck'
#  2]
# ['HAM_0000361' 'ISIC_0032199' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0000462' 'ISIC_0033869' "Bowen's disease" 'histo' 60.0 'female'
#  'lower extremity' 2]
# ['HAM_0004363' 'ISIC_0026857' "Bowen's disease" 'histo' 55.0 'male' 'face'
#  2]
# ['HAM_0004060' 'ISIC_0030825' "Bowen's disease" 'histo' 40.0 'male' 'face'
#  2]
# ['HAM_0006036' 'ISIC_0029713' "Bowen's disease" 'histo' 85.0 'male' 'back'
#  2]
# ['HAM_0005668' 'ISIC_0028370' "Bowen's disease" 'histo' 60.0 'male' 'face'
#  2]
# ['HAM_0000239' 'ISIC_0033866' "Bowen's disease" 'histo' 80.0 'male' 'face'
#  2]
# ['HAM_0007008' 'ISIC_0030036' "Bowen's disease" 'histo' 60.0 'male' 'hand'
#  2]
# ['HAM_0005705' 'ISIC_0024654' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0000931' 'ISIC_0028820' "Bowen's disease" 'histo' 80.0 'male'
#  'lower extremity' 2]
# ['HAM_0004034' 'ISIC_0027829' "Bowen's disease" 'histo' 55.0 'female'
#  'face' 2]
# ['HAM_0006902' 'ISIC_0031506' "Bowen's disease" 'histo' 70.0 'male' 'hand'
#  2]
# ['HAM_0003949' 'ISIC_0027254' "Bowen's disease" 'histo' 75.0 'male' 'face'
#  2]
# ['HAM_0004472' 'ISIC_0025368' "Bowen's disease" 'histo' 40.0 'female'
#  'face' 2]
# ['HAM_0003910' 'ISIC_0026194' "Bowen's disease" 'histo' 30.0 'male' 'face'
#  2]
# ['HAM_0001474' 'ISIC_0026765' "Bowen's disease" 'histo' 55.0 'female'
#  'chest' 2]
# ['HAM_0001505' 'ISIC_0024511' "Bowen's disease" 'histo' 55.0 'female'
#  'face' 2]
# ['HAM_0006252' 'ISIC_0026040' "Bowen's disease" 'histo' 70.0 'female'
#  'face' 2]
# ['HAM_0006024' 'ISIC_0029830' "Bowen's disease" 'histo' 60.0 'male' 'face'
#  2]
# ['HAM_0006024' 'ISIC_0027884' "Bowen's disease" 'histo' 60.0 'male' 'face'
#  2]
# ['HAM_0006220' 'ISIC_0028517' "Bowen's disease" 'histo' 60.0 'male'
#  'upper extremity' 2]
# ['HAM_0004809' 'ISIC_0031108' "Bowen's disease" 'histo' 60.0 'male' 'face'
#  2]
# ['HAM_0001036' 'ISIC_0027588' "Bowen's disease" 'histo' 50.0 'female'
#  'face' 2]
# ['HAM_0004384' 'ISIC_0029025' "Bowen's disease" 'histo' 70.0 'male' 'face'
#  2]
# ['HAM_0004462' 'ISIC_0027334' "Bowen's disease" 'histo' 45.0 'male'
#  'trunk' 2]
# ['HAM_0001152' 'ISIC_0030133' "Bowen's disease" 'histo' 65.0 'male' 'face'
#  2]
# ['HAM_0004282' 'ISIC_0033811' "Bowen's disease" 'histo' 65.0 'female'
#  'face' 2]
# ['HAM_0000545' 'ISIC_0026650' "Bowen's disease" 'histo' 70.0 'male' 'face'
#  2]
# ['HAM_0000193' 'ISIC_0030877' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0000193' 'ISIC_0027950' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0006180' 'ISIC_0027615' "Bowen's disease" 'histo' 70.0 'male'
#  'upper extremity' 2]
# ['HAM_0006180' 'ISIC_0028990' "Bowen's disease" 'histo' 70.0 'male'
#  'upper extremity' 2]
# ['HAM_0004282' 'ISIC_0033358' "Bowen's disease" 'histo' 65.0 'female'
#  'face' 2]
# ['HAM_0000356' 'ISIC_0030655' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0004282' 'ISIC_0033151' "Bowen's disease" 'histo' 65.0 'female'
#  'face' 2]
# ['HAM_0000020' 'ISIC_0031922' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0006442' 'ISIC_0032947' "Bowen's disease" 'histo' 70.0 'male' 'hand'
#  2]
# ['HAM_0004592' 'ISIC_0029141' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0005579' 'ISIC_0029309' "Bowen's disease" 'histo' 80.0 'male' 'face'
#  2]
# ['HAM_0005579' 'ISIC_0028393' "Bowen's disease" 'histo' 80.0 'male' 'face'
#  2]
# ['HAM_0004034' 'ISIC_0024948' "Bowen's disease" 'histo' 55.0 'female'
#  'face' 2]
# ['HAM_0001565' 'ISIC_0028619' "Bowen's disease" 'histo' 60.0 'female'
#  'face' 2]
# ['HAM_0001576' 'ISIC_0033705' "Bowen's disease" 'histo' 60.0 'male' 'face'
#  2]
# ['HAM_0005705' 'ISIC_0031430' "Bowen's disease" 'histo' 75.0 'female'
#  'lower extremity' 2]
# ['HAM_0002867' 'ISIC_0033084' "Bowen's disease" 'histo' 40.0 'male'
#  'abdomen' 2]
# ['HAM_0002867' 'ISIC_0033550' "Bowen's disease" 'histo' 40.0 'male'
#  'abdomen' 2]
# ['HAM_0002867' 'ISIC_0033536' "Bowen's disease" 'histo' 40.0 'male'
#  'abdomen' 2]
# ['HAM_0000239' 'ISIC_0032854' "Bowen's disease" 'histo' 80.0 'male' 'face'
#  2]
# ['HAM_0003521' 'ISIC_0032258' 'Melanoma' 'histo' 70.0 'female' 'back' 5]

# %%
path_part_1 = '/Users/tommasocapecchi/Datasets/HAM10000/Images'
dataset = []
df['dx'] = df['dx'].astype('category')
for image_name in df['image_id'][:10]:
    image_path = os.path.join(path_part_1, image_name +'.jpg')
    df['img_path'] = image_path
    df['label'] = df['dx'].cat.codes.
    image = plt.imread(image_path, format='jpg')
    dataset.append(image)
    
dataset = np.array(dataset)
dataset.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-2da5c87aaab8> in <module>
#       5     image_path = os.path.join(path_part_1, image_name +'.jpg')
#       6     df['img_path'] = image_path
# ----> 7     df['label'] = df['dx'].cat.codes.dx
#       8     image = plt.imread(image_path, format='jpg')
#       9     dataset.append(image)
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'dx'

# %% [markdown]
# Althought the dataset contains more that 10000 images, after the preprocessing we just eliminated half of them because they were not classified using a scientific method. Those images that have been deleted are indeed those whose were classified as 'consensus' and 'follow_up'.
#
# After this brief pre-processing, we are left with 5409 images, each with a dimension of 450x600, and they are indeed RGB images.

# %%
encoder = preprocessing.LabelEncoder()
encoder.fit_transform(df['dx'])
encoder.classes_

df.drop()
# Out:
# array(['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc'], dtype=object)
